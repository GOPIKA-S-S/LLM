# %% [markdown]
# <a href="https://colab.research.google.com/github/GOPIKA-S-S/LLM/blob/main/2348518_LLM_Lab2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dotenv
# !pip install langchain
# !pip install langchain-groq

# %%
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
import os

# %%
load_dotenv()

# Retrieve the API key from the environment variable
api_key = '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'
# Print the API key to ensure it is loaded correctly (for debugging purposes, remove this in production)
print(api_key)
# Out:
# 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

# %%
model = ChatGroq(api_key = api_key ,model_name = 'llama3-8b-8192')

# %%
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is table tennis')
# Out:
# "Table tennis, also known as ping-pong, is a fast-paced and exciting indoor sport played on a table with small rackets and a lightweight ball. Here's a brief overview:\n\n**Objective:** The objective of table tennis is to hit the ball back and forth with your opponent in a way that makes it difficult for them to return. Points are scored when a player fails to return the ball or makes an error.\n\n**Equipment:** A standard table tennis table is 9 feet (2.74 meters) long, 5 feet (1.52 meters) wide, and 30 inches (76 cm) high. The tables have a smooth, flat surface and are divided into two halves by a net that stands 6 inches (15 cm) high in the middle.\n\n**Gameplay:** Players use small rackets (also called paddles or bats) to hit the ball, which is made of celluloid, plastic, or other lightweight materials. A match is typically played best two out of three games, with each game played to 11 points.\n\n**Basic rules:**\n\n1. A serve starts the game, with the ball bouncing on the serve
# ...

# %% [markdown]
# Question Answering

# %%
template = (
    """
    you're question answering expert
answer : {answer}
"""
)

# %%
prompt = PromptTemplate.from_template(template=template)

# %%
chain =  prompt | model | parser

# %%
answer = """
tell me about LLM
"""

# %%
result = chain.invoke({'answer':answer})
print(result)
# Out:
# LLM stands for Large Language Model, which refers to a type of artificial intelligence (AI) model that is trained on a massive dataset of text to generate human-like language. LLMs are designed to understand and generate natural language, and are typically used for tasks such as language translation, text summarization, and chatbots.
#
# Characteristics of LLMs:
#
# 1. **Scale**: LLMs are trained on enormous datasets, often in the order of billions of words, which allows them to learn patterns and relationships in language.
# 2. **Depth**: LLMs have multiple layers, with each layer processing the input text and passing it on to the next layer. This allows them to capture complex relationships and nuances in language.
# 3. **Language understanding**: LLMs are trained to understand the meaning of text, including syntax, semantics, and pragmatics.
# ...

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma-7b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is LLM')
# Out:
# '**LLM (Large Language Model)**\n\nLLMs (Large Language Models) are a class of **generative AI models** trained on vast amounts of text data. They can understand and generate human language, making them capable of various tasks such as:\n\n* **Text generation:** Writing stories, poems, code, emails, and other written content.\n* **Conversation:** Engaging in natural and coherent conversations.\n* **Translation:** Translating languages in real-time.\n* **Summarization:** Summarizing long documents and articles.\n* **Question-answering:** Providing answers to questions based on the text they have been trained on.\n\n\n**How they work:**\n\nLLMs are trained on massive datasets of text and code, allowing them to learn the patterns and relationships in language. Their architecture consists of:\n\n* **Encoder:** Processes the input text and converts it into a numerical representation.\n* **Decoder:** Generates new text based on the encoded representation.\n* **Attention mechanism:** Allows
# ...

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma2-9b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is LLM')
# Out:
# "LLM stands for **Large Language Model**.\n\nIt's a type of artificial intelligence (AI) that excels at understanding and generating human-like text.\n\nHere's a breakdown:\n\n* **Large:** These models are trained on massive datasets of text and code, containing billions or even trillions of words. This vast amount of data allows them to learn complex patterns and relationships within language.\n* **Language:** LLMs are specifically designed to process and generate text. They can understand the nuances of language, including grammar, syntax, and even some aspects of meaning and context.\n* **Model:** An LLM is a mathematical model that represents knowledge about language. It uses this knowledge to perform various tasks, such as:\n\n    * **Text Generation:** Writing stories, articles, poems, and other types of creative content.\n    * **Translation:** Converting text from one language to another.\n    * **Summarization:** Condensing large amounts of text into shorter summaries.\n    
# ...

# %% [markdown]
# From Gemini

# %% [markdown]
# ![Screenshot (138).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-11 105025.png](data:image/png;base64,...)
